# %%
import numpy as np
import pandas as pd

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models.keyedvectors import KeyedVectors

# %%
glove2word2vec(glove_input_file="./model_300/vectors.txt", word2vec_output_file="./model_300/gensim_glove_vectors.txt")
# Out:
# (336145, 300)

# %%
glove_model = KeyedVectors.load_word2vec_format("./model_300/gensim_glove_vectors.txt", binary=False)

# %%
glove_model.vocab
# Out:
# {'suyo_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e700>,
#  'prpers_pronoun': <gensim.models.keyedvectors.Vocab at 0x13949e1f0>,
#  'suyo_determiner': <gensim.models.keyedvectors.Vocab at 0x13949ea30>,
#  'el_pronoun': <gensim.models.keyedvectors.Vocab at 0x13949e370>,
#  'el_seu_determiner': <gensim.models.keyedvectors.Vocab at 0x13949e2b0>,
#  'el_seu_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e550>,
#  'ce_determiner': <gensim.models.keyedvectors.Vocab at 0x13949eac0>,
#  'el_determiner': <gensim.models.keyedvectors.Vocab at 0x13949ea90>,
#  'ce_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e340>,
#  'aquel_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e490>,
#  'aquel_determiner': <gensim.models.keyedvectors.Vocab at 0x13949ea00>,
#  'en_preposition': <gensim.models.keyedvectors.Vocab at 0x13949e2e0>,
#  'cap_noun': <gensim.models.keyedvectors.Vocab at 0x13949e970>,
#  'on_adverb': <gensim.models.keyedvectors.Vocab at 0x13949e160>,
#  'de_preposition': <gensim.models.keyedvectors.Vocab at 0x138b4d4f0>,
#  'cuánto_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x118270970>,
#  'simple_adjective': <gensim.models.keyedvectors.Vocab at 0x138e102e0>,
#  'control_noun': <gensim.models.keyedvectors.Vocab at 0x105bb7f10>,
#  'este_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x138bfa3a0>,
#  'este_determiner': <gensim.models.keyedvectors.Vocab at 0x138bfa100>,
#  'fan_noun': <gensim.models.keyedvectors.Vocab at 0x139456fa0>,
#  'suyo_adjective': <gensim.models.keyedvectors.Vocab at 0x13949e6d0>,
#  'mío_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13949ec40>,
#  'radio_noun': <gensim.models.keyedvectors.Vocab at 0x13949e190>,
#  'this_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e5b0>,
#  'this_determiner': <gensim.models.keyedvectors.Vocab at 0x13949e100>,
#  'tuyo_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e1c0>,
#  'capital_noun': <gensim.models.keyedvectors.Vocab at 0x13949e400>,
#  'on_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x13949ef10>,
#  'final_noun': <gensim.models.keyedvectors.Vocab at 0x13949ec10>,
#  'on_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x13949e730>,
#  'que_pronoun': <gensim.models.keyedvectors.Vocab at 0x13949e4f0>,
#  'reunir_verb': <gensim.models.keyedvectors.Vocab at 0x13949e220>,
#  'seu_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x139466040>,
#  'son_determiner': <gensim.models.keyedvectors.Vocab at 0x1394660a0>,
#  'son_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x139466130>,
#  'cuánto_adjective': <gensim.models.keyedvectors.Vocab at 0x139466190>,
#  'mon_determiner': <gensim.models.keyedvectors.Vocab at 0x1394661f0>,
#  'mon_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x139466250>,
#  'que_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x1394662b0>,
#  'tirar_verb': <gensim.models.keyedvectors.Vocab at 0x139466310>,
#  'tour_noun': <gensim.models.keyedvectors.Vocab at 0x139466370>,
#  'celo_noun': <gensim.models.keyedvectors.Vocab at 0x1394663d0>,
#  'entre_preposition': <gensim.models.keyedvectors.Vocab at 0x139466430>,
#  'qué_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x139466490>,
#  'take_verb': <gensim.models.keyedvectors.Vocab at 0x1394664f0>,
#  'base_noun': <gensim.models.keyedvectors.Vocab at 0x139466550>,
#  'por_preposition': <gensim.models.keyedvectors.Vocab at 0x1394665b0>,
#  'sentir_verb': <gensim.models.keyedvectors.Vocab at 0x139466610>,
#  'egin_verb': <gensim.models.keyedvectors.Vocab at 0x139466670>,
#  'horrible_adjective': <gensim.models.keyedvectors.Vocab at 0x1394666d0>,
#  'principal_adjective': <gensim.models.keyedvectors.Vocab at 0x139466730>,
#  'quant_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x139466790>,
#  'seu_adjective': <gensim.models.keyedvectors.Vocab at 0x1394667f0>,
#  'some_determiner': <gensim.models.keyedvectors.Vocab at 0x139466850>,
#  'test_noun': <gensim.models.keyedvectors.Vocab at 0x1394668b0>,
#  'variable_adjective': <gensim.models.keyedvectors.Vocab at 0x139466910>,
#  'a_preposition': <gensim.models.keyedvectors.Vocab at 0x139466970>,
#  'acabar_verb': <gensim.models.keyedvectors.Vocab at 0x1394669d0>,
#  'indispensable_adjective': <gensim.models.keyedvectors.Vocab at 0x139466a30>,
#  'lo_pronoun': <gensim.models.keyedvectors.Vocab at 0x139466a90>,
#  'sobre_preposition': <gensim.models.keyedvectors.Vocab at 0x139466af0>,
#  'ton_determiner': <gensim.models.keyedvectors.Vocab at 0x139466b50>,
#  'ton_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x139466bb0>,
#  'error_noun': <gensim.models.keyedvectors.Vocab at 0x139466c10>,
#  'ese_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x139466c70>,
#  'ese_determiner': <gensim.models.keyedvectors.Vocab at 0x139466cd0>,
#  'izan_verb': <gensim.models.keyedvectors.Vocab at 0x139466d30>,
#  'local_adjective': <gensim.models.keyedvectors.Vocab at 0x139466d90>,
#  'mío_determiner': <gensim.models.keyedvectors.Vocab at 0x139466df0>,
#  'miserable_adjective': <gensim.models.keyedvectors.Vocab at 0x139466e50>,
#  'tuyo_determiner': <gensim.models.keyedvectors.Vocab at 0x139466eb0>,
#  'auto_noun': <gensim.models.keyedvectors.Vocab at 0x139466f10>,
#  'director_noun': <gensim.models.keyedvectors.Vocab at 0x139466f70>,
#  'familiar_adjective': <gensim.models.keyedvectors.Vocab at 0x139466fd0>,
#  'lo_determiner': <gensim.models.keyedvectors.Vocab at 0x13946a070>,
#  'partir_verb': <gensim.models.keyedvectors.Vocab at 0x13946a0d0>,
#  'quant_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a130>,
#  'real_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a190>,
#  'terrible_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a1f0>,
#  'vuestro_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13946a250>,
#  'animal_noun': <gensim.models.keyedvectors.Vocab at 0x13946a2b0>,
#  'aumentar_verb': <gensim.models.keyedvectors.Vocab at 0x13946a310>,
#  'canal_noun': <gensim.models.keyedvectors.Vocab at 0x13946a370>,
#  'el_seu_pronoun': <gensim.models.keyedvectors.Vocab at 0x13946a3d0>,
#  'global_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a430>,
#  'quin_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a490>,
#  'quin_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x13946a4f0>,
#  'social_adjective': <gensim.models.keyedvectors.Vocab at 0x13946a550>,
#  'apuntar_verb': <gensim.models.keyedvectors.Vocab at 0x13946a5b0>,
#  'aquel_pronoun': <gensim.models.keyedvectors.Vocab at 0x13946a610>,
#  'arena_noun': <gensim.models.keyedvectors.Vocab at 0x13946a670>,
#  'bar_noun': <gensim.models.keyedvectors.Vocab at 0x13946a6d0>,
#  'ce_pronoun': <gensim.models.keyedvectors.Vocab at 0x13946a730>,
#  'editorial_noun': <gensim.models.keyedvectors.Vocab at 0x13946a790>,
#  'el_teu_determiner': <gensim.models.keyedvectors.Vocab at 0x13946a7f0>,
#  'el_teu_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13946a850>,
#  'his_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13946a8b0>,
#  'mal_adverb': <gensim.models.keyedvectors.Vocab at 0x13946a910>,
#  'marca_noun': <gensim.models.keyedvectors.Vocab at 0x13946a970>,
#  'metro_noun': <gensim.models.keyedvectors.Vocab at 0x13946a9d0>,
#  'normal_adjective': <gensim.models.keyedvectors.Vocab at 0x13946aa30>,
#  'notable_adjective': <gensim.models.keyedvectors.Vocab at 0x13946aa90>,
#  'nuestro_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x13946aaf0>,
#  'obstacle_noun': <gensim.models.keyedvectors.Vocab at 0x13946ab50>,
#  'record_noun': <gensim.models.keyedvectors.Vocab at 0x13946abb0>,
#  'recordar_verb': <gensim.models.keyedvectors.Vocab at 0x13946ac10>,
#  'aquí_adverb': <gensim.models.keyedvectors.Vocab at 0x13946ac70>,
#  'bien_adverb': <gensim.models.keyedvectors.Vocab at 0x13946acd0>,
#  'broma_noun': <gensim.models.keyedvectors.Vocab at 0x13946ad30>,
#  'entrada_noun': <gensim.models.keyedvectors.Vocab at 0x13946ad90>,
#  'le_pronoun': <gensim.models.keyedvectors.Vocab at 0x13946adf0>,
#  'no_adverb': <gensim.models.keyedvectors.Vocab at 0x13946ae50>,
#  'onde_adverb': <gensim.models.keyedvectors.Vocab at 0x13946aeb0>,
#  'onde_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x13946af10>,
#  'onde_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x13946af70>,
#  'pista_noun': <gensim.models.keyedvectors.Vocab at 0x13946afd0>,
#  'viable_adjective': <gensim.models.keyedvectors.Vocab at 0x138940070>,
#  'where_adverb': <gensim.models.keyedvectors.Vocab at 0x1389400d0>,
#  'your_determiner': <gensim.models.keyedvectors.Vocab at 0x138940130>,
#  'your_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x138940190>,
#  'alegrar_verb': <gensim.models.keyedvectors.Vocab at 0x1389401f0>,
#  'carta_noun': <gensim.models.keyedvectors.Vocab at 0x138940250>,
#  'cuánto_adverb': <gensim.models.keyedvectors.Vocab at 0x1389402b0>,
#  'cuánto_determiner': <gensim.models.keyedvectors.Vocab at 0x138940310>,
#  'dirigir_verb': <gensim.models.keyedvectors.Vocab at 0x138940370>,
#  'dossier_noun': <gensim.models.keyedvectors.Vocab at 0x1389403d0>,
#  'egon_verb': <gensim.models.keyedvectors.Vocab at 0x138940430>,
#  'en_general_adverb': <gensim.models.keyedvectors.Vocab at 0x138940490>,
#  'exterior_adjective': <gensim.models.keyedvectors.Vocab at 0x1389404f0>,
#  'film_noun': <gensim.models.keyedvectors.Vocab at 0x1386de1f0>,
#  'medio_noun': <gensim.models.keyedvectors.Vocab at 0x1386cdc10>,
#  'picar_verb': <gensim.models.keyedvectors.Vocab at 0x138e12e20>,
#  'pot_noun': <gensim.models.keyedvectors.Vocab at 0x138bfa3d0>,
#  'suyo_pronoun': <gensim.models.keyedvectors.Vocab at 0x138940550>,
#  'this_pronoun': <gensim.models.keyedvectors.Vocab at 0x1389405b0>,
#  'total_adjective': <gensim.models.keyedvectors.Vocab at 0x138940610>,
#  'unir_verb': <gensim.models.keyedvectors.Vocab at 0x138940670>,
#  'Barcelona_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389406d0>,
#  'Jesús_properNoun': <gensim.models.keyedvectors.Vocab at 0x138940730>,
#  'civil_adjective': <gensim.models.keyedvectors.Vocab at 0x138940790>,
#  'contar_verb': <gensim.models.keyedvectors.Vocab at 0x1389407f0>,
#  'destacar_verb': <gensim.models.keyedvectors.Vocab at 0x138940850>,
#  'e-mail_noun': <gensim.models.keyedvectors.Vocab at 0x1389408b0>,
#  'eman_verb': <gensim.models.keyedvectors.Vocab at 0x138940910>,
#  'esperar_verb': <gensim.models.keyedvectors.Vocab at 0x138940970>,
#  'estirar_verb': <gensim.models.keyedvectors.Vocab at 0x1389409d0>,
#  'expansion_noun': <gensim.models.keyedvectors.Vocab at 0x138940a30>,
#  'flexible_adjective': <gensim.models.keyedvectors.Vocab at 0x138940a90>,
#  'hartu_verb': <gensim.models.keyedvectors.Vocab at 0x138940af0>,
#  'how_much_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x138940b50>,
#  'oral_adjective': <gensim.models.keyedvectors.Vocab at 0x138940bb0>,
#  'part_noun': <gensim.models.keyedvectors.Vocab at 0x138940c10>,
#  'penal_adjective': <gensim.models.keyedvectors.Vocab at 0x138940c70>,
#  'piano_noun': <gensim.models.keyedvectors.Vocab at 0x138940cd0>,
#  'plan_noun': <gensim.models.keyedvectors.Vocab at 0x138940d30>,
#  'prendre_verb': <gensim.models.keyedvectors.Vocab at 0x138940d90>,
#  'sensible_adjective': <gensim.models.keyedvectors.Vocab at 0x138940df0>,
#  'singular_adjective': <gensim.models.keyedvectors.Vocab at 0x138940e50>,
#  'sortir_verb': <gensim.models.keyedvectors.Vocab at 0x138940eb0>,
#  'triste_adjective': <gensim.models.keyedvectors.Vocab at 0x138940f10>,
#  'web_noun': <gensim.models.keyedvectors.Vocab at 0x138940f70>,
#  'where_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x138940fd0>,
#  'where_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x138950070>,
#  'zoo_noun': <gensim.models.keyedvectors.Vocab at 0x1389500d0>,
#  'Bilbao_properNoun': <gensim.models.keyedvectors.Vocab at 0x138950130>,
#  'ERC_noun': <gensim.models.keyedvectors.Vocab at 0x138950190>,
#  'Navarra_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389501f0>,
#  'camp_noun': <gensim.models.keyedvectors.Vocab at 0x138950250>,
#  'compatible_adjective': <gensim.models.keyedvectors.Vocab at 0x1389502b0>,
#  'cruel_adjective': <gensim.models.keyedvectors.Vocab at 0x138950310>,
#  'drama_noun': <gensim.models.keyedvectors.Vocab at 0x138950370>,
#  'enviar_verb': <gensim.models.keyedvectors.Vocab at 0x1389503d0>,
#  'expert_noun': <gensim.models.keyedvectors.Vocab at 0x138950430>,
#  'extension_noun': <gensim.models.keyedvectors.Vocab at 0x138950490>,
#  'fin_noun': <gensim.models.keyedvectors.Vocab at 0x1389504f0>,
#  'infant_noun': <gensim.models.keyedvectors.Vocab at 0x138950550>,
#  'kapti_verb': <gensim.models.keyedvectors.Vocab at 0x1389505b0>,
#  'komenci_verb': <gensim.models.keyedvectors.Vocab at 0x138950610>,
#  'manera_noun': <gensim.models.keyedvectors.Vocab at 0x138950670>,
#  'posar_verb': <gensim.models.keyedvectors.Vocab at 0x1389506d0>,
#  'presa_noun': <gensim.models.keyedvectors.Vocab at 0x138950730>,
#  'qué_pronoun': <gensim.models.keyedvectors.Vocab at 0x138950790>,
#  'recuperar_verb': <gensim.models.keyedvectors.Vocab at 0x1389507f0>,
#  'sartu_verb': <gensim.models.keyedvectors.Vocab at 0x138950850>,
#  'superior_adjective': <gensim.models.keyedvectors.Vocab at 0x1389508b0>,
#  'union_noun': <gensim.models.keyedvectors.Vocab at 0x138950910>,
#  'Iraq_properNoun': <gensim.models.keyedvectors.Vocab at 0x138950970>,
#  'Joan_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389509d0>,
#  'actual_adjective': <gensim.models.keyedvectors.Vocab at 0x138950a30>,
#  'alguno_determiner': <gensim.models.keyedvectors.Vocab at 0x138950a90>,
#  'alguno_pronoun': <gensim.models.keyedvectors.Vocab at 0x138950af0>,
#  'bajar_verb': <gensim.models.keyedvectors.Vocab at 0x138950b50>,
#  'banda_noun': <gensim.models.keyedvectors.Vocab at 0x138950bb0>,
#  'bus_noun': <gensim.models.keyedvectors.Vocab at 0x138950c10>,
#  'central_adjective': <gensim.models.keyedvectors.Vocab at 0x138950c70>,
#  'company_noun': <gensim.models.keyedvectors.Vocab at 0x138950cd0>,
#  'completamente_adverb': <gensim.models.keyedvectors.Vocab at 0x138950d30>,
#  'cuánto_pronoun': <gensim.models.keyedvectors.Vocab at 0x138950d90>,
#  'digital_adjective': <gensim.models.keyedvectors.Vocab at 0x138950df0>,
#  'eksigi_verb': <gensim.models.keyedvectors.Vocab at 0x138950e50>,
#  'empresa_noun': <gensim.models.keyedvectors.Vocab at 0x138950eb0>,
#  'encantar_verb': <gensim.models.keyedvectors.Vocab at 0x138950f10>,
#  'estimar_verb': <gensim.models.keyedvectors.Vocab at 0x138950f70>,
#  'euro_noun': <gensim.models.keyedvectors.Vocab at 0x138950fd0>,
#  'internet_noun': <gensim.models.keyedvectors.Vocab at 0x13894b070>,
#  'material_noun': <gensim.models.keyedvectors.Vocab at 0x13894b0d0>,
#  'mode_noun': <gensim.models.keyedvectors.Vocab at 0x13894b130>,
#  'mortal_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b190>,
#  'municipal_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b1f0>,
#  'net_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b250>,
#  'ordenar_verb': <gensim.models.keyedvectors.Vocab at 0x13894b2b0>,
#  'particular_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b310>,
#  'pena_noun': <gensim.models.keyedvectors.Vocab at 0x13894b370>,
#  'portar_verb': <gensim.models.keyedvectors.Vocab at 0x13894b3d0>,
#  'qué_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b430>,
#  'rock_noun': <gensim.models.keyedvectors.Vocab at 0x13894b490>,
#  'sur_preposition': <gensim.models.keyedvectors.Vocab at 0x13894b4f0>,
#  'susceptible_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b550>,
#  'tenir_verb': <gensim.models.keyedvectors.Vocab at 0x13894b5b0>,
#  'that_determiner': <gensim.models.keyedvectors.Vocab at 0x13894b610>,
#  'tribunal_noun': <gensim.models.keyedvectors.Vocab at 0x13894b670>,
#  'Carlos_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b6d0>,
#  'David_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b730>,
#  'Fernando_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b790>,
#  'Juan_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b7f0>,
#  'Lleida_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b850>,
#  'PSOE_noun': <gensim.models.keyedvectors.Vocab at 0x13894b8b0>,
#  'Washington_properNoun': <gensim.models.keyedvectors.Vocab at 0x13894b910>,
#  'akra_adjective': <gensim.models.keyedvectors.Vocab at 0x13894b970>,
#  'application_noun': <gensim.models.keyedvectors.Vocab at 0x13894b9d0>,
#  'balance_noun': <gensim.models.keyedvectors.Vocab at 0x13894ba30>,
#  'bikain_adjective': <gensim.models.keyedvectors.Vocab at 0x13894ba90>,
#  'bon_adjective': <gensim.models.keyedvectors.Vocab at 0x13894baf0>,
#  'capa_noun': <gensim.models.keyedvectors.Vocab at 0x13894bb50>,
#  'cara_noun': <gensim.models.keyedvectors.Vocab at 0x13894bbb0>,
#  'chat_noun': <gensim.models.keyedvectors.Vocab at 0x13894bc10>,
#  'considerar_verb': <gensim.models.keyedvectors.Vocab at 0x13894bc70>,
#  'convenir_verb': <gensim.models.keyedvectors.Vocab at 0x13894bcd0>,
#  'course_noun': <gensim.models.keyedvectors.Vocab at 0x13894bd30>,
#  'distribution_noun': <gensim.models.keyedvectors.Vocab at 0x13894bd90>,
#  'drop_verb': <gensim.models.keyedvectors.Vocab at 0x13894bdf0>,
#  'electoral_adjective': <gensim.models.keyedvectors.Vocab at 0x13894be50>,
#  'falta_noun': <gensim.models.keyedvectors.Vocab at 0x13894beb0>,
#  'festival_noun': <gensim.models.keyedvectors.Vocab at 0x13894bf10>,
#  'final_adjective': <gensim.models.keyedvectors.Vocab at 0x13894bf70>,
#  'firma_noun': <gensim.models.keyedvectors.Vocab at 0x13894bfd0>,
#  'fuel_noun': <gensim.models.keyedvectors.Vocab at 0x13895d070>,
#  'gala_noun': <gensim.models.keyedvectors.Vocab at 0x13895d0d0>,
#  'idea_noun': <gensim.models.keyedvectors.Vocab at 0x13895d130>,
#  'inevitable_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d190>,
#  'instigi_verb': <gensim.models.keyedvectors.Vocab at 0x13895d1f0>,
#  'instrumental_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d250>,
#  'intentar_verb': <gensim.models.keyedvectors.Vocab at 0x13895d2b0>,
#  'interior_noun': <gensim.models.keyedvectors.Vocab at 0x13895d310>,
#  'invariable_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d370>,
#  'jarri_verb': <gensim.models.keyedvectors.Vocab at 0x13895d3d0>,
#  'kondamni_verb': <gensim.models.keyedvectors.Vocab at 0x13895d430>,
#  'lavabo_noun': <gensim.models.keyedvectors.Vocab at 0x13895d490>,
#  'legal_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d4f0>,
#  'llevar_verb': <gensim.models.keyedvectors.Vocab at 0x13895d550>,
#  'original_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d5b0>,
#  'panorama_noun': <gensim.models.keyedvectors.Vocab at 0x13895d610>,
#  'parar_verb': <gensim.models.keyedvectors.Vocab at 0x13895d670>,
#  'passage_noun': <gensim.models.keyedvectors.Vocab at 0x13895d6d0>,
#  'per_preposition': <gensim.models.keyedvectors.Vocab at 0x13895d730>,
#  'perseguir_verb': <gensim.models.keyedvectors.Vocab at 0x13895d790>,
#  'pipe_noun': <gensim.models.keyedvectors.Vocab at 0x13895d7f0>,
#  'posterior_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d850>,
#  'probable_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d8b0>,
#  'provisional_adjective': <gensim.models.keyedvectors.Vocab at 0x13895d910>,
#  'quand_adverb': <gensim.models.keyedvectors.Vocab at 0x13895d970>,
#  'quand_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x13895d9d0>,
#  'que_subordinatingConjunction': <gensim.models.keyedvectors.Vocab at 0x13895da30>,
#  'responsable_adjective': <gensim.models.keyedvectors.Vocab at 0x13895da90>,
#  'son_noun': <gensim.models.keyedvectors.Vocab at 0x13895daf0>,
#  'that_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x13895db50>,
#  'valorar_verb': <gensim.models.keyedvectors.Vocab at 0x13895dbb0>,
#  'Granada_properNoun': <gensim.models.keyedvectors.Vocab at 0x13895dc10>,
#  'Luis_properNoun': <gensim.models.keyedvectors.Vocab at 0x13895dc70>,
#  'Pau_properNoun': <gensim.models.keyedvectors.Vocab at 0x13895dcd0>,
#  'Sofia_properNoun': <gensim.models.keyedvectors.Vocab at 0x13895dd30>,
#  'accorder_verb': <gensim.models.keyedvectors.Vocab at 0x13895dd90>,
#  'agenda_noun': <gensim.models.keyedvectors.Vocab at 0x13895ddf0>,
#  'anual_adjective': <gensim.models.keyedvectors.Vocab at 0x13895de50>,
#  'aparato_noun': <gensim.models.keyedvectors.Vocab at 0x13895deb0>,
#  'arsenal_noun': <gensim.models.keyedvectors.Vocab at 0x13895df10>,
#  'atacar_verb': <gensim.models.keyedvectors.Vocab at 0x13895df70>,
#  'bastante_adverb': <gensim.models.keyedvectors.Vocab at 0x13895dfd0>,
#  'buscar_verb': <gensim.models.keyedvectors.Vocab at 0x138958070>,
#  'capital_adjective': <gensim.models.keyedvectors.Vocab at 0x1389580d0>,
#  'carro_noun': <gensim.models.keyedvectors.Vocab at 0x138958130>,
#  'cinta_noun': <gensim.models.keyedvectors.Vocab at 0x138958190>,
#  'club_noun': <gensim.models.keyedvectors.Vocab at 0x1389581f0>,
#  'collection_noun': <gensim.models.keyedvectors.Vocab at 0x138958250>,
#  'como_adverb': <gensim.models.keyedvectors.Vocab at 0x1389582b0>,
#  'como_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x138958310>,
#  'comparable_adjective': <gensim.models.keyedvectors.Vocab at 0x138958370>,
#  'comprendre_verb': <gensim.models.keyedvectors.Vocab at 0x1389583d0>,
#  'considerable_adjective': <gensim.models.keyedvectors.Vocab at 0x138958430>,
#  'continuar_verb': <gensim.models.keyedvectors.Vocab at 0x138958490>,
#  'cultivar_verb': <gensim.models.keyedvectors.Vocab at 0x1389584f0>,
#  'editor_noun': <gensim.models.keyedvectors.Vocab at 0x138958550>,
#  'enseguida_adverb': <gensim.models.keyedvectors.Vocab at 0x1389585b0>,
#  'escala_noun': <gensim.models.keyedvectors.Vocab at 0x138958610>,
#  'face_noun': <gensim.models.keyedvectors.Vocab at 0x138958670>,
#  'favorable_adjective': <gensim.models.keyedvectors.Vocab at 0x1389586d0>,
#  'fregar_verb': <gensim.models.keyedvectors.Vocab at 0x138958730>,
#  'girl_noun': <gensim.models.keyedvectors.Vocab at 0x138958790>,
#  'golf_noun': <gensim.models.keyedvectors.Vocab at 0x1389587f0>,
#  'hasta_preposition': <gensim.models.keyedvectors.Vocab at 0x138958850>,
#  'ideal_adjective': <gensim.models.keyedvectors.Vocab at 0x1389588b0>,
#  'impulso_noun': <gensim.models.keyedvectors.Vocab at 0x138958910>,
#  'incompatible_adjective': <gensim.models.keyedvectors.Vocab at 0x138958970>,
#  'interminable_adjective': <gensim.models.keyedvectors.Vocab at 0x1389589d0>,
#  'kie_adverb': <gensim.models.keyedvectors.Vocab at 0x138958a30>,
#  'lamentar_verb': <gensim.models.keyedvectors.Vocab at 0x138958a90>,
#  'longitud_noun': <gensim.models.keyedvectors.Vocab at 0x138958af0>,
#  'maleta_noun': <gensim.models.keyedvectors.Vocab at 0x138958b50>,
#  'marcar_verb': <gensim.models.keyedvectors.Vocab at 0x138958bb0>,
#  'menor_adjective': <gensim.models.keyedvectors.Vocab at 0x138958c10>,
#  'mil_numeral': <gensim.models.keyedvectors.Vocab at 0x138958c70>,
#  'mirar_verb': <gensim.models.keyedvectors.Vocab at 0x138958cd0>,
#  'molestar_verb': <gensim.models.keyedvectors.Vocab at 0x138958d30>,
#  'moral_adjective': <gensim.models.keyedvectors.Vocab at 0x138958d90>,
#  'moral_noun': <gensim.models.keyedvectors.Vocab at 0x138958df0>,
#  'ni_coordinatingConjunction': <gensim.models.keyedvectors.Vocab at 0x138958e50>,
#  'oriental_adjective': <gensim.models.keyedvectors.Vocab at 0x138958eb0>,
#  'pastor_noun': <gensim.models.keyedvectors.Vocab at 0x138958f10>,
#  'poste_adverb': <gensim.models.keyedvectors.Vocab at 0x138958f70>,
#  'promotion_noun': <gensim.models.keyedvectors.Vocab at 0x138958fd0>,
#  'quan_adverb': <gensim.models.keyedvectors.Vocab at 0x138960070>,
#  'quan_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x1389600d0>,
#  'que_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x138960130>,
#  'radical_adjective': <gensim.models.keyedvectors.Vocab at 0x138960190>,
#  'sentimental_adjective': <gensim.models.keyedvectors.Vocab at 0x1389601f0>,
#  'sol_noun': <gensim.models.keyedvectors.Vocab at 0x138960250>,
#  'superar_verb': <gensim.models.keyedvectors.Vocab at 0x1389602b0>,
#  'superficial_adjective': <gensim.models.keyedvectors.Vocab at 0x138960310>,
#  'tallar_verb': <gensim.models.keyedvectors.Vocab at 0x138960370>,
#  'tanto_determiner': <gensim.models.keyedvectors.Vocab at 0x1389603d0>,
#  'tanto_pronoun': <gensim.models.keyedvectors.Vocab at 0x138960430>,
#  'taxi_noun': <gensim.models.keyedvectors.Vocab at 0x138960490>,
#  'tornar_verb': <gensim.models.keyedvectors.Vocab at 0x1389604f0>,
#  'vital_adjective': <gensim.models.keyedvectors.Vocab at 0x138960550>,
#  'Antonio_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389605b0>,
#  'Gaza_properNoun': <gensim.models.keyedvectors.Vocab at 0x138960610>,
#  'Israel_properNoun': <gensim.models.keyedvectors.Vocab at 0x138960670>,
#  'Joseph_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389606d0>,
#  'Madrid_properNoun': <gensim.models.keyedvectors.Vocab at 0x138960730>,
#  'Martin_properNoun': <gensim.models.keyedvectors.Vocab at 0x138960790>,
#  'Nicaragua_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389607f0>,
#  'Paris_properNoun': <gensim.models.keyedvectors.Vocab at 0x138960850>,
#  'abocar_verb': <gensim.models.keyedvectors.Vocab at 0x1389608b0>,
#  'acordar_verb': <gensim.models.keyedvectors.Vocab at 0x138960910>,
#  'afrontar_verb': <gensim.models.keyedvectors.Vocab at 0x138960970>,
#  'alcalde_noun': <gensim.models.keyedvectors.Vocab at 0x1389609d0>,
#  'antaŭe_adverb': <gensim.models.keyedvectors.Vocab at 0x138960a30>,
#  'article_noun': <gensim.models.keyedvectors.Vocab at 0x138960a90>,
#  'boy_noun': <gensim.models.keyedvectors.Vocab at 0x138960af0>,
#  'cable_noun': <gensim.models.keyedvectors.Vocab at 0x138960b50>,
#  'café_noun': <gensim.models.keyedvectors.Vocab at 0x138960bb0>,
#  'com_adverb': <gensim.models.keyedvectors.Vocab at 0x138960c10>,
#  'confusion_noun': <gensim.models.keyedvectors.Vocab at 0x138960c70>,
#  'corredor_noun': <gensim.models.keyedvectors.Vocab at 0x138960cd0>,
#  'desviar_verb': <gensim.models.keyedvectors.Vocab at 0x138960d30>,
#  'el_meu_determiner': <gensim.models.keyedvectors.Vocab at 0x138960d90>,
#  'el_meu_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x138960df0>,
#  'espantar_verb': <gensim.models.keyedvectors.Vocab at 0x138960e50>,
#  'estar_verb': <gensim.models.keyedvectors.Vocab at 0x138960eb0>,
#  'este_pronoun': <gensim.models.keyedvectors.Vocab at 0x138960f10>,
#  'explotar_verb': <gensim.models.keyedvectors.Vocab at 0x138960f70>,
#  'failure_noun': <gensim.models.keyedvectors.Vocab at 0x138960fd0>,
#  'fax_noun': <gensim.models.keyedvectors.Vocab at 0x138967070>,
#  'file_noun': <gensim.models.keyedvectors.Vocab at 0x1389670d0>,
#  'fiscal_adjective': <gensim.models.keyedvectors.Vocab at 0x138967130>,
#  'font_noun': <gensim.models.keyedvectors.Vocab at 0x138967190>,
#  'fuga_noun': <gensim.models.keyedvectors.Vocab at 0x1389671f0>,
#  'gasolina_noun': <gensim.models.keyedvectors.Vocab at 0x138967250>,
#  'get_verb': <gensim.models.keyedvectors.Vocab at 0x1389672b0>,
#  'how_much_determiner': <gensim.models.keyedvectors.Vocab at 0x138967310>,
#  'industrial_adjective': <gensim.models.keyedvectors.Vocab at 0x138967370>,
#  'irregular_adjective': <gensim.models.keyedvectors.Vocab at 0x1389673d0>,
#  'le_determiner': <gensim.models.keyedvectors.Vocab at 0x138967430>,
#  'liberal_adjective': <gensim.models.keyedvectors.Vocab at 0x138967490>,
#  'link_noun': <gensim.models.keyedvectors.Vocab at 0x1389674f0>,
#  'manage_verb': <gensim.models.keyedvectors.Vocab at 0x138967550>,
#  'many_pronoun': <gensim.models.keyedvectors.Vocab at 0x1389675b0>,
#  'monumental_adjective': <gensim.models.keyedvectors.Vocab at 0x138967610>,
#  'moto_noun': <gensim.models.keyedvectors.Vocab at 0x138967670>,
#  'mucho_determiner': <gensim.models.keyedvectors.Vocab at 0x1389676d0>,
#  'obertura_noun': <gensim.models.keyedvectors.Vocab at 0x138967730>,
#  'occidental_adjective': <gensim.models.keyedvectors.Vocab at 0x138967790>,
#  'pintura_noun': <gensim.models.keyedvectors.Vocab at 0x1389677f0>,
#  'potable_adjective': <gensim.models.keyedvectors.Vocab at 0x138967850>,
#  'programa_noun': <gensim.models.keyedvectors.Vocab at 0x1389678b0>,
#  'provincial_adjective': <gensim.models.keyedvectors.Vocab at 0x138967910>,
#  'quan_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x138967970>,
#  'quand_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x1389679d0>,
#  'quant_pronoun': <gensim.models.keyedvectors.Vocab at 0x138967a30>,
#  'radar_noun': <gensim.models.keyedvectors.Vocab at 0x138967a90>,
#  'repartir_verb': <gensim.models.keyedvectors.Vocab at 0x138967af0>,
#  'sí_adverb': <gensim.models.keyedvectors.Vocab at 0x138967b50>,
#  'señor_noun': <gensim.models.keyedvectors.Vocab at 0x138967bb0>,
#  'secular_adjective': <gensim.models.keyedvectors.Vocab at 0x138967c10>,
#  'seguir_verb': <gensim.models.keyedvectors.Vocab at 0x138967c70>,
#  'si_subordinatingConjunction': <gensim.models.keyedvectors.Vocab at 0x138967cd0>,
#  'that_pronoun': <gensim.models.keyedvectors.Vocab at 0x138967d30>,
#  'transfer_noun': <gensim.models.keyedvectors.Vocab at 0x138967d90>,
#  'venir_verb': <gensim.models.keyedvectors.Vocab at 0x138967df0>,
#  'veto_noun': <gensim.models.keyedvectors.Vocab at 0x138967e50>,
#  'vista_noun': <gensim.models.keyedvectors.Vocab at 0x138967eb0>,
#  'ĉiu_pronoun': <gensim.models.keyedvectors.Vocab at 0x138967f10>,
#  'Alberto_properNoun': <gensim.models.keyedvectors.Vocab at 0x138967f70>,
#  'Carles_properNoun': <gensim.models.keyedvectors.Vocab at 0x138967fd0>,
#  'Galicia_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff070>,
#  'Hussein_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff0d0>,
#  'Javier_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff130>,
#  'Jorge_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff190>,
#  'José_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff1f0>,
#  'Kosovo_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff250>,
#  'Lima_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff2b0>,
#  'Linux_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff310>,
#  'Manuel_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff370>,
#  'Maria_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff3d0>,
#  'Martín_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff430>,
#  'Miguel_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff490>,
#  'PP_noun': <gensim.models.keyedvectors.Vocab at 0x1389ff4f0>,
#  'Pedro_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff550>,
#  'Rafa_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff5b0>,
#  'Roberto_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff610>,
#  'Shakespeare_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff670>,
#  'Tolosa_properNoun': <gensim.models.keyedvectors.Vocab at 0x1389ff6d0>,
#  'agradable_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ff730>,
#  'aguantar_verb': <gensim.models.keyedvectors.Vocab at 0x1389ff790>,
#  'animar_verb': <gensim.models.keyedvectors.Vocab at 0x1389ff7f0>,
#  'aro_noun': <gensim.models.keyedvectors.Vocab at 0x1389ff850>,
#  'arrancar_verb': <gensim.models.keyedvectors.Vocab at 0x1389ff8b0>,
#  'beat_verb': <gensim.models.keyedvectors.Vocab at 0x1389ff910>,
#  'brutal_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ff970>,
#  'casa_noun': <gensim.models.keyedvectors.Vocab at 0x1389ff9d0>,
#  'casual_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ffa30>,
#  'com_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x1389ffa90>,
#  'commission_noun': <gensim.models.keyedvectors.Vocab at 0x1389ffaf0>,
#  'conseguir_verb': <gensim.models.keyedvectors.Vocab at 0x1389ffb50>,
#  'criminal_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ffbb0>,
#  'crucial_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ffc10>,
#  'el_que_pronoun': <gensim.models.keyedvectors.Vocab at 0x1389ffc70>,
#  'el_que_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x1389ffcd0>,
#  'enredar_verb': <gensim.models.keyedvectors.Vocab at 0x1389ffd30>,
#  'fragment_noun': <gensim.models.keyedvectors.Vocab at 0x1389ffd90>,
#  'front_noun': <gensim.models.keyedvectors.Vocab at 0x1389ffdf0>,
#  'his_determiner': <gensim.models.keyedvectors.Vocab at 0x1389ffe50>,
#  'integral_adjective': <gensim.models.keyedvectors.Vocab at 0x1389ffeb0>,
#  'investigar_verb': <gensim.models.keyedvectors.Vocab at 0x1389fff10>,
#  'invisible_adjective': <gensim.models.keyedvectors.Vocab at 0x1389fff70>,
#  'irreversible_adjective': <gensim.models.keyedvectors.Vocab at 0x1389fffd0>,
#  'jo_verb': <gensim.models.keyedvectors.Vocab at 0x138a09070>,
#  'kiu_pronoun': <gensim.models.keyedvectors.Vocab at 0x138a090d0>,
#  'mío_adjective': <gensim.models.keyedvectors.Vocab at 0x138a09130>,
#  'mal_noun': <gensim.models.keyedvectors.Vocab at 0x138a09190>,
#  'malhelpi_verb': <gensim.models.keyedvectors.Vocab at 0x138a091f0>,
#  'manga_noun': <gensim.models.keyedvectors.Vocab at 0x138a09250>,
#  'mental_adjective': <gensim.models.keyedvectors.Vocab at 0x138a092b0>,
#  'mirada_noun': <gensim.models.keyedvectors.Vocab at 0x138a09310>,
#  'moment_noun': <gensim.models.keyedvectors.Vocab at 0x138a09370>,
#  'niño_noun': <gensim.models.keyedvectors.Vocab at 0x138a093d0>,
#  'où_adverb': <gensim.models.keyedvectors.Vocab at 0x138a09430>,
#  'paper_noun': <gensim.models.keyedvectors.Vocab at 0x138a09490>,
#  'paso_noun': <gensim.models.keyedvectors.Vocab at 0x138a094f0>,
#  'permanent_adjective': <gensim.models.keyedvectors.Vocab at 0x138a09550>,
#  'pila_noun': <gensim.models.keyedvectors.Vocab at 0x138a095b0>,
#  'place_noun': <gensim.models.keyedvectors.Vocab at 0x138a09610>,
#  'plataforma_noun': <gensim.models.keyedvectors.Vocab at 0x138a09670>,
#  'pobre_adjective': <gensim.models.keyedvectors.Vocab at 0x138a096d0>,
#  'preparar_verb': <gensim.models.keyedvectors.Vocab at 0x138a09730>,
#  'punta_noun': <gensim.models.keyedvectors.Vocab at 0x138a09790>,
#  'quant_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x138a097f0>,
#  'range_noun': <gensim.models.keyedvectors.Vocab at 0x138a09850>,
#  'resto_noun': <gensim.models.keyedvectors.Vocab at 0x138a098b0>,
#  'ring_noun': <gensim.models.keyedvectors.Vocab at 0x138a09910>,
#  'rodar_verb': <gensim.models.keyedvectors.Vocab at 0x138a09970>,
#  'rural_adjective': <gensim.models.keyedvectors.Vocab at 0x138a099d0>,
#  'sala_noun': <gensim.models.keyedvectors.Vocab at 0x138a09a30>,
#  'stand_noun': <gensim.models.keyedvectors.Vocab at 0x138a09a90>,
#  'talent_noun': <gensim.models.keyedvectors.Vocab at 0x138a09af0>,
#  'target_noun': <gensim.models.keyedvectors.Vocab at 0x138a09b50>,
#  'temporal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a09bb0>,
#  'terminal_noun': <gensim.models.keyedvectors.Vocab at 0x138a09c10>,
#  'teu_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x138a09c70>,
#  'torre_noun': <gensim.models.keyedvectors.Vocab at 0x138a09cd0>,
#  'visible_adjective': <gensim.models.keyedvectors.Vocab at 0x138a09d30>,
#  'Anthony_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09d90>,
#  'Asia_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09df0>,
#  'Bernard_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09e50>,
#  'Buenos_Aires_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09eb0>,
#  'Enric_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09f10>,
#  'Euskadi_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09f70>,
#  'Francisco_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a09fd0>,
#  'Guadalupe_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a14070>,
#  'Jaime_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a140d0>,
#  'Jaume_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a14130>,
#  'Josep_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a14190>,
#  'Lluís_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a141f0>,
#  'Nicolas_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a14250>,
#  'Pamplona_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a142b0>,
#  'Stephen_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a14310>,
#  'adaptar_verb': <gensim.models.keyedvectors.Vocab at 0x138a14370>,
#  'ampliar_verb': <gensim.models.keyedvectors.Vocab at 0x138a143d0>,
#  'anterior_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14430>,
#  'aquest_demonstrativePronoun': <gensim.models.keyedvectors.Vocab at 0x138a14490>,
#  'aquest_determiner': <gensim.models.keyedvectors.Vocab at 0x138a144f0>,
#  'arriba_adverb': <gensim.models.keyedvectors.Vocab at 0x138a14550>,
#  'banal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a145b0>,
#  'blog_noun': <gensim.models.keyedvectors.Vocab at 0x138a14610>,
#  'boom_noun': <gensim.models.keyedvectors.Vocab at 0x138a14670>,
#  'cambio_noun': <gensim.models.keyedvectors.Vocab at 0x138a146d0>,
#  'charge_noun': <gensim.models.keyedvectors.Vocab at 0x138a14730>,
#  'chip_noun': <gensim.models.keyedvectors.Vocab at 0x138a14790>,
#  'circuit_noun': <gensim.models.keyedvectors.Vocab at 0x138a147f0>,
#  'com_relativePronoun': <gensim.models.keyedvectors.Vocab at 0x138a14850>,
#  'coma_noun': <gensim.models.keyedvectors.Vocab at 0x138a148b0>,
#  'conductor_noun': <gensim.models.keyedvectors.Vocab at 0x138a14910>,
#  'confiar_verb': <gensim.models.keyedvectors.Vocab at 0x138a14970>,
#  'consulta_noun': <gensim.models.keyedvectors.Vocab at 0x138a149d0>,
#  'coral_noun': <gensim.models.keyedvectors.Vocab at 0x138a14a30>,
#  'delta_noun': <gensim.models.keyedvectors.Vocab at 0x138a14a90>,
#  'eduki_verb': <gensim.models.keyedvectors.Vocab at 0x138a14af0>,
#  'enterrar_verb': <gensim.models.keyedvectors.Vocab at 0x138a14b50>,
#  'entrar_verb': <gensim.models.keyedvectors.Vocab at 0x138a14bb0>,
#  'eventual_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14c10>,
#  'fil_noun': <gensim.models.keyedvectors.Vocab at 0x138a14c70>,
#  'fila_noun': <gensim.models.keyedvectors.Vocab at 0x138a14cd0>,
#  'foto_noun': <gensim.models.keyedvectors.Vocab at 0x138a14d30>,
#  'gradual_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14d90>,
#  'gris_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14df0>,
#  'have_verb': <gensim.models.keyedvectors.Vocab at 0x138a14e50>,
#  'humor_noun': <gensim.models.keyedvectors.Vocab at 0x138a14eb0>,
#  'implicar_verb': <gensim.models.keyedvectors.Vocab at 0x138a14f10>,
#  'individual_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14f70>,
#  'inferior_adjective': <gensim.models.keyedvectors.Vocab at 0x138a14fd0>,
#  'intervenir_verb': <gensim.models.keyedvectors.Vocab at 0x138a19070>,
#  'invention_noun': <gensim.models.keyedvectors.Vocab at 0x138a190d0>,
#  'irresponsable_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19130>,
#  'konfirmi_verb': <gensim.models.keyedvectors.Vocab at 0x138a19190>,
#  'leader_noun': <gensim.models.keyedvectors.Vocab at 0x138a191f0>,
#  'marchar_verb': <gensim.models.keyedvectors.Vocab at 0x138a19250>,
#  'massacre_noun': <gensim.models.keyedvectors.Vocab at 0x138a192b0>,
#  'material_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19310>,
#  'momento_noun': <gensim.models.keyedvectors.Vocab at 0x138a19370>,
#  'mucho_pronoun': <gensim.models.keyedvectors.Vocab at 0x138a193d0>,
#  'natural_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19430>,
#  'oferta_noun': <gensim.models.keyedvectors.Vocab at 0x138a19490>,
#  'pal_noun': <gensim.models.keyedvectors.Vocab at 0x138a194f0>,
#  'paseo_noun': <gensim.models.keyedvectors.Vocab at 0x138a19550>,
#  'pastoral_adjective': <gensim.models.keyedvectors.Vocab at 0x138a195b0>,
#  'pegar_verb': <gensim.models.keyedvectors.Vocab at 0x138a19610>,
#  'perceptible_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19670>,
#  'performance_noun': <gensim.models.keyedvectors.Vocab at 0x138a196d0>,
#  'plural_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19730>,
#  'quel_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19790>,
#  'quel_interrogativePronoun': <gensim.models.keyedvectors.Vocab at 0x138a197f0>,
#  'qui_pronoun': <gensim.models.keyedvectors.Vocab at 0x138a19850>,
#  'raise_verb': <gensim.models.keyedvectors.Vocab at 0x138a198b0>,
#  'rango_noun': <gensim.models.keyedvectors.Vocab at 0x138a19910>,
#  'regulation_noun': <gensim.models.keyedvectors.Vocab at 0x138a19970>,
#  'rumor_noun': <gensim.models.keyedvectors.Vocab at 0x138a199d0>,
#  'saltar_verb': <gensim.models.keyedvectors.Vocab at 0x138a19a30>,
#  'seguidor_noun': <gensim.models.keyedvectors.Vocab at 0x138a19a90>,
#  'servir_verb': <gensim.models.keyedvectors.Vocab at 0x138a19af0>,
#  'set_noun': <gensim.models.keyedvectors.Vocab at 0x138a19b50>,
#  'some_pronoun': <gensim.models.keyedvectors.Vocab at 0x138a19bb0>,
#  'soprano_noun': <gensim.models.keyedvectors.Vocab at 0x138a19c10>,
#  'sort_noun': <gensim.models.keyedvectors.Vocab at 0x138a19c70>,
#  'subject_noun': <gensim.models.keyedvectors.Vocab at 0x138a19cd0>,
#  'tan_adverb': <gensim.models.keyedvectors.Vocab at 0x138a19d30>,
#  'terminal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19d90>,
#  'tipo_noun': <gensim.models.keyedvectors.Vocab at 0x138a19df0>,
#  'tocar_verb': <gensim.models.keyedvectors.Vocab at 0x138a19e50>,
#  'trace_noun': <gensim.models.keyedvectors.Vocab at 0x138a19eb0>,
#  'transmission_noun': <gensim.models.keyedvectors.Vocab at 0x138a19f10>,
#  'transportar_verb': <gensim.models.keyedvectors.Vocab at 0x138a19f70>,
#  'triple_adjective': <gensim.models.keyedvectors.Vocab at 0x138a19fd0>,
#  'tubo_noun': <gensim.models.keyedvectors.Vocab at 0x138a1c070>,
#  'tute_adverb': <gensim.models.keyedvectors.Vocab at 0x138a1c0d0>,
#  'tuyo_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1c130>,
#  'virus_noun': <gensim.models.keyedvectors.Vocab at 0x138a1c190>,
#  'vuestro_determiner': <gensim.models.keyedvectors.Vocab at 0x138a1c1f0>,
#  'vulgar_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1c250>,
#  'Adam_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c2b0>,
#  'Alaska_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c310>,
#  'Alexander_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c370>,
#  'Alicante_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c3d0>,
#  'Antoni_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c430>,
#  'Aznar_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c490>,
#  'Blair_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c4f0>,
#  'Bush_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c550>,
#  'Chávez_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c5b0>,
#  'Clinton_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c610>,
#  'Cuenca_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c670>,
#  'Daniel_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c6d0>,
#  'Dennis_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c730>,
#  'Dominique_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c790>,
#  'Emma_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c7f0>,
#  'Eric_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c850>,
#  'George_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c8b0>,
#  'Girona_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c910>,
#  'Isabel_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c970>,
#  'Jacques_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1c9d0>,
#  'Jan_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1ca30>,
#  'Johnson_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1ca90>,
#  'Jordan_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1caf0>,
#  'Kennedy_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cb50>,
#  'Kurdistan_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cbb0>,
#  'Lewis_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cc10>,
#  'Lorena_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cc70>,
#  'Lucas_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1ccd0>,
#  'Lyon_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cd30>,
#  'Mark_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cd90>,
#  'Marta_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cdf0>,
#  'Merkel_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1ce50>,
#  'Morgan_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1ceb0>,
#  'Nobel_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cf10>,
#  'Parker_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cf70>,
#  'Paulo_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1cfd0>,
#  'Philippe_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e070>,
#  'Portugal_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e0d0>,
#  'Rubalcaba_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e130>,
#  'Ruiz_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e190>,
#  'Valencia_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e1f0>,
#  'Warner_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e250>,
#  'William_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e2b0>,
#  'Zapatero_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e310>,
#  'Zaragoza_properNoun': <gensim.models.keyedvectors.Vocab at 0x138a1e370>,
#  'a_causa_de_preposition': <gensim.models.keyedvectors.Vocab at 0x138a1e3d0>,
#  'a_lot_of_determiner': <gensim.models.keyedvectors.Vocab at 0x138a1e430>,
#  'a_lot_of_pronoun': <gensim.models.keyedvectors.Vocab at 0x138a1e490>,
#  'abandonar_verb': <gensim.models.keyedvectors.Vocab at 0x138a1e4f0>,
#  'accent_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e550>,
#  'accord_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e5b0>,
#  'acumular_verb': <gensim.models.keyedvectors.Vocab at 0x138a1e610>,
#  'admirable_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1e670>,
#  'agent_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e6d0>,
#  'alto_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e730>,
#  'anormal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1e790>,
#  'aparte_adverb': <gensim.models.keyedvectors.Vocab at 0x138a1e7f0>,
#  'arma_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e850>,
#  'arrêter_verb': <gensim.models.keyedvectors.Vocab at 0x138a1e8b0>,
#  'audible_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1e910>,
#  'bandera_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e970>,
#  'bandit_noun': <gensim.models.keyedvectors.Vocab at 0x138a1e9d0>,
#  'barra_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ea30>,
#  'cambiar_verb': <gensim.models.keyedvectors.Vocab at 0x138a1ea90>,
#  'campus_noun': <gensim.models.keyedvectors.Vocab at 0x138a1eaf0>,
#  'canon_noun': <gensim.models.keyedvectors.Vocab at 0x138a1eb50>,
#  'carretera_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ebb0>,
#  'cercle_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ec10>,
#  'col_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ec70>,
#  'continental_adjective': <gensim.models.keyedvectors.Vocab at 0x138a1ecd0>,
#  'cura_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ed30>,
#  'dépasser_verb': <gensim.models.keyedvectors.Vocab at 0x138a1ed90>,
#  'davant_adverb': <gensim.models.keyedvectors.Vocab at 0x138a1edf0>,
#  'dedicar_verb': <gensim.models.keyedvectors.Vocab at 0x138a1ee50>,
#  'delimitar_verb': <gensim.models.keyedvectors.Vocab at 0x138a1eeb0>,
#  'destino_noun': <gensim.models.keyedvectors.Vocab at 0x138a1ef10>,
#  'devenir_verb': <gensim.models.keyedvectors.Vocab at 0x138a1ef70>,
#  'direction_noun': <gensim.models.keyedvectors.Vocab at 0x138a1efd0>,
#  'disturb_verb': <gensim.models.keyedvectors.Vocab at 0x138a37070>,
#  'divertir_verb': <gensim.models.keyedvectors.Vocab at 0x138a370d0>,
#  'doctor_noun': <gensim.models.keyedvectors.Vocab at 0x138a37130>,
#  'don_noun': <gensim.models.keyedvectors.Vocab at 0x138a37190>,
#  'dormir_verb': <gensim.models.keyedvectors.Vocab at 0x138a371f0>,
#  'egoki_adjective': <gensim.models.keyedvectors.Vocab at 0x138a37250>,
#  'encourage_verb': <gensim.models.keyedvectors.Vocab at 0x138a372b0>,
#  'entendre_verb': <gensim.models.keyedvectors.Vocab at 0x138a37310>,
#  'era_noun': <gensim.models.keyedvectors.Vocab at 0x138a37370>,
#  'excepcional_adjective': <gensim.models.keyedvectors.Vocab at 0x138a373d0>,
#  'fatal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a37430>,
#  'fiable_adjective': <gensim.models.keyedvectors.Vocab at 0x138a37490>,
#  'forma_noun': <gensim.models.keyedvectors.Vocab at 0x138a374f0>,
#  'formal_adjective': <gensim.models.keyedvectors.Vocab at 0x138a37550>,
#  'gaire_adverb': <gensim.models.keyedvectors.Vocab at 0x138a375b0>,
#  'general_adjective': <gensim.models.keyedvectors.Vocab at 0x138a37610>,
# ...
#  'Limoges_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088910>,
#  'Louis_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088970>,
#  'Melilla_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390889d0>,
#  'Milà_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088a30>,
#  'Montserrat_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088a90>,
#  'Murcia_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088af0>,
#  'París_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088b50>,
#  'Pere_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088bb0>,
#  'Rabat_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088c10>,
#  'Ramon_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088c70>,
#  'Richard_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088cd0>,
#  'Robert_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088d30>,
#  'Salvador_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088d90>,
#  'Simon_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088df0>,
#  'Thomas_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088e50>,
#  'Tonga_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088eb0>,
#  'València_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088f10>,
#  'Victoria_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088f70>,
#  'Zimbabwe_properNoun': <gensim.models.keyedvectors.Vocab at 0x139088fd0>,
#  'abismo_noun': <gensim.models.keyedvectors.Vocab at 0x13909b070>,
#  'abonar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b0d0>,
#  'accessible_adjective': <gensim.models.keyedvectors.Vocab at 0x13909b130>,
#  'agafar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b190>,
#  'alegre_adjective': <gensim.models.keyedvectors.Vocab at 0x13909b1f0>,
#  'amaso_noun': <gensim.models.keyedvectors.Vocab at 0x13909b250>,
#  'anunciar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b2b0>,
#  'argument_noun': <gensim.models.keyedvectors.Vocab at 0x13909b310>,
#  'arreglar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b370>,
#  'atera_verb': <gensim.models.keyedvectors.Vocab at 0x13909b3d0>,
#  'banc_noun': <gensim.models.keyedvectors.Vocab at 0x13909b430>,
#  'card_noun': <gensim.models.keyedvectors.Vocab at 0x13909b490>,
#  'carrera_noun': <gensim.models.keyedvectors.Vocab at 0x13909b4f0>,
#  'casino_noun': <gensim.models.keyedvectors.Vocab at 0x13909b550>,
#  'cerca_adverb': <gensim.models.keyedvectors.Vocab at 0x13909b5b0>,
#  'chance_noun': <gensim.models.keyedvectors.Vocab at 0x13909b610>,
#  'consistent_adjective': <gensim.models.keyedvectors.Vocab at 0x13909b670>,
#  'construir_verb': <gensim.models.keyedvectors.Vocab at 0x13909b6d0>,
#  'cordial_adjective': <gensim.models.keyedvectors.Vocab at 0x13909b730>,
#  'cultural_adjective': <gensim.models.keyedvectors.Vocab at 0x13909b790>,
#  'curar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b7f0>,
#  'despertar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b850>,
#  'disminuir_verb': <gensim.models.keyedvectors.Vocab at 0x13909b8b0>,
#  'dismiss_verb': <gensim.models.keyedvectors.Vocab at 0x13909b910>,
#  'entregar_verb': <gensim.models.keyedvectors.Vocab at 0x13909b970>,
#  'eragin_verb': <gensim.models.keyedvectors.Vocab at 0x13909b9d0>,
#  'evitar_verb': <gensim.models.keyedvectors.Vocab at 0x13909ba30>,
#  'expert_adjective': <gensim.models.keyedvectors.Vocab at 0x13909ba90>,
#  'federal_adjective': <gensim.models.keyedvectors.Vocab at 0x13909baf0>,
#  'fini_verb': <gensim.models.keyedvectors.Vocab at 0x13909bb50>,
#  'fondre_verb': <gensim.models.keyedvectors.Vocab at 0x13909bbb0>,
#  'formidable_adjective': <gensim.models.keyedvectors.Vocab at 0x13909bc10>,
#  'frontal_adjective': <gensim.models.keyedvectors.Vocab at 0x13909bc70>,
#  'gel_noun': <gensim.models.keyedvectors.Vocab at 0x13909bcd0>,
#  'goal_noun': <gensim.models.keyedvectors.Vocab at 0x13909bd30>,
#  'golpe_noun': <gensim.models.keyedvectors.Vocab at 0x13909bd90>,
#  'grain_noun': <gensim.models.keyedvectors.Vocab at 0x13909bdf0>,
#  'hall_noun': <gensim.models.keyedvectors.Vocab at 0x13909be50>,
#  'horror_noun': <gensim.models.keyedvectors.Vocab at 0x13909beb0>,
#  'hospital_noun': <gensim.models.keyedvectors.Vocab at 0x13909bf10>,
#  'incident_noun': <gensim.models.keyedvectors.Vocab at 0x13909bf70>,
#  'inclinar_verb': <gensim.models.keyedvectors.Vocab at 0x13909bfd0>,
#  'insignificant_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e070>,
#  'investir_verb': <gensim.models.keyedvectors.Vocab at 0x13909e0d0>,
#  'jazz_noun': <gensim.models.keyedvectors.Vocab at 0x13909e130>,
#  'kruda_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e190>,
#  'litoral_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e1f0>,
#  'local_noun': <gensim.models.keyedvectors.Vocab at 0x13909e250>,
#  'mail_noun': <gensim.models.keyedvectors.Vocab at 0x13909e2b0>,
#  'management_noun': <gensim.models.keyedvectors.Vocab at 0x13909e310>,
#  'mandato_noun': <gensim.models.keyedvectors.Vocab at 0x13909e370>,
#  'medieval_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e3d0>,
#  'mineral_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e430>,
#  'modo_noun': <gensim.models.keyedvectors.Vocab at 0x13909e490>,
#  'monitor_noun': <gensim.models.keyedvectors.Vocab at 0x13909e4f0>,
#  'motor_noun': <gensim.models.keyedvectors.Vocab at 0x13909e550>,
#  'mozo_noun': <gensim.models.keyedvectors.Vocab at 0x13909e5b0>,
#  'neutral_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e610>,
#  'non_adverb': <gensim.models.keyedvectors.Vocab at 0x13909e670>,
#  'nuestro_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e6d0>,
#  'nuestro_determiner': <gensim.models.keyedvectors.Vocab at 0x13909e730>,
#  'pagar_verb': <gensim.models.keyedvectors.Vocab at 0x13909e790>,
#  'palpable_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e7f0>,
#  'papa_noun': <gensim.models.keyedvectors.Vocab at 0x13909e850>,
#  'paquet_noun': <gensim.models.keyedvectors.Vocab at 0x13909e8b0>,
#  'pasta_noun': <gensim.models.keyedvectors.Vocab at 0x13909e910>,
#  'peculiar_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e970>,
#  'personal_adjective': <gensim.models.keyedvectors.Vocab at 0x13909e9d0>,
#  'perspectiva_noun': <gensim.models.keyedvectors.Vocab at 0x13909ea30>,
#  'popular_adjective': <gensim.models.keyedvectors.Vocab at 0x13909ea90>,
#  'poste_noun': <gensim.models.keyedvectors.Vocab at 0x13909eaf0>,
#  'prison_noun': <gensim.models.keyedvectors.Vocab at 0x13909eb50>,
#  'propaganda_noun': <gensim.models.keyedvectors.Vocab at 0x13909ebb0>,
#  'provocar_verb': <gensim.models.keyedvectors.Vocab at 0x13909ec10>,
#  'pudor_noun': <gensim.models.keyedvectors.Vocab at 0x13909ec70>,
#  'quedar_verb': <gensim.models.keyedvectors.Vocab at 0x13909ecd0>,
#  'rando_noun': <gensim.models.keyedvectors.Vocab at 0x13909ed30>,
#  'rate_noun': <gensim.models.keyedvectors.Vocab at 0x13909ed90>,
#  'red_noun': <gensim.models.keyedvectors.Vocab at 0x13909edf0>,
#  'release_noun': <gensim.models.keyedvectors.Vocab at 0x13909ee50>,
#  'revista_noun': <gensim.models.keyedvectors.Vocab at 0x13909eeb0>,
#  'robot_noun': <gensim.models.keyedvectors.Vocab at 0x13909ef10>,
#  'route_noun': <gensim.models.keyedvectors.Vocab at 0x13909ef70>,
#  'saisir_verb': <gensim.models.keyedvectors.Vocab at 0x13909efd0>,
#  'secret_noun': <gensim.models.keyedvectors.Vocab at 0x139093070>,
#  'separar_verb': <gensim.models.keyedvectors.Vocab at 0x1390930d0>,
#  'sign_noun': <gensim.models.keyedvectors.Vocab at 0x139093130>,
#  'software_noun': <gensim.models.keyedvectors.Vocab at 0x139093190>,
#  'spot_noun': <gensim.models.keyedvectors.Vocab at 0x1390931f0>,
#  'suite_noun': <gensim.models.keyedvectors.Vocab at 0x139093250>,
#  'temple_noun': <gensim.models.keyedvectors.Vocab at 0x1390932b0>,
#  'total_noun': <gensim.models.keyedvectors.Vocab at 0x139093310>,
#  'trampa_noun': <gensim.models.keyedvectors.Vocab at 0x139093370>,
#  'trial_noun': <gensim.models.keyedvectors.Vocab at 0x1390933d0>,
#  'trimestre_noun': <gensim.models.keyedvectors.Vocab at 0x139093430>,
#  'tuj_adverb': <gensim.models.keyedvectors.Vocab at 0x139093490>,
#  'universal_adjective': <gensim.models.keyedvectors.Vocab at 0x1390934f0>,
#  'utzi_verb': <gensim.models.keyedvectors.Vocab at 0x139093550>,
#  'via_possessivePronoun': <gensim.models.keyedvectors.Vocab at 0x1390935b0>,
#  'vigla_adjective': <gensim.models.keyedvectors.Vocab at 0x139093610>,
#  'vote_noun': <gensim.models.keyedvectors.Vocab at 0x139093670>,
#  'vuestro_adjective': <gensim.models.keyedvectors.Vocab at 0x1390936d0>,
#  'zinc_noun': <gensim.models.keyedvectors.Vocab at 0x139093730>,
#  'ĉiu_determiner': <gensim.models.keyedvectors.Vocab at 0x139093790>,
#  'ŝelo_noun': <gensim.models.keyedvectors.Vocab at 0x1390937f0>,
#  'Alabama_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093850>,
#  'Albert_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390938b0>,
#  'Alex_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093910>,
#  'Alexandre_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093970>,
#  'Ankara_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390939d0>,
#  'Apple_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093a30>,
#  'Baltasar_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093a90>,
#  'Bangladesh_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093af0>,
#  'Bernat_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093b50>,
#  'Carla_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093bb0>,
#  'Castro_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093c10>,
#  'Charles_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093c70>,
#  'Christopher_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093cd0>,
#  'Colomer_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093d30>,
#  'Corbacho_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093d90>,
#  'Cuba_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093df0>,
#  'Diego_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093e50>,
#  'Domingo_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093eb0>,
#  'Fernández_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093f10>,
#  'Ferran_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093f70>,
#  'Figo_properNoun': <gensim.models.keyedvectors.Vocab at 0x139093fd0>,
#  'Fox_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae070>,
#  'Francesc_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae0d0>,
#  'Franco_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae130>,
#  'Gabriel_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae190>,
#  'García_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae1f0>,
#  'González_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae250>,
#  'Gore_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae2b0>,
#  'Guyana_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae310>,
#  'Isabelle_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae370>,
#  'James_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae3d0>,
#  'John_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae430>,
#  'Jordi_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae490>,
#  'Juana_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae4f0>,
#  'Julia_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae550>,
#  'López_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae5b0>,
#  'Laurent_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae610>,
#  'Madagascar_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae670>,
#  'Manchester_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae6d0>,
#  'Marc_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae730>,
#  'March_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae790>,
#  'Margaret_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae7f0>,
#  'Martí_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae850>,
#  'Mary_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae8b0>,
#  'Messi_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae910>,
#  'Michel_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae970>,
#  'Microsoft_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390ae9d0>,
#  'Miller_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aea30>,
#  'Montenegro_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aea90>,
#  'Montevideo_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aeaf0>,
#  'Moore_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aeb50>,
#  'Murray_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aebb0>,
#  'Otegi_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aec10>,
#  'Ourense_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aec70>,
#  'Pérez_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aecd0>,
#  'Peter_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aed30>,
#  'Potter_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aed90>,
#  'Putin_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aedf0>,
#  'Renault_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aee50>,
#  'Richardson_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aeeb0>,
#  'Rodríguez_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aef10>,
#  'Roger_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aef70>,
#  'Roma_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390aefd0>,
#  'Rossi_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9070>,
#  'Sabadell_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b90d0>,
#  'Salamanca_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9130>,
#  'Samoa_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9190>,
#  'Samuel_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b91f0>,
#  'Santander_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9250>,
#  'Sarkozy_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b92b0>,
#  'Sebastián_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9310>,
#  'Sevilla_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9370>,
#  'Smith_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b93d0>,
#  'Tarantino_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9430>,
#  'Tarragona_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9490>,
#  'Tim_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b94f0>,
#  'Toulouse_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9550>,
#  'Valladolid_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b95b0>,
#  'Wilson_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9610>,
#  'Young_properNoun': <gensim.models.keyedvectors.Vocab at 0x1390b9670>,
#  'abajo_adverb': <gensim.models.keyedvectors.Vocab at 0x1390b96d0>,
#  'abdomen_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9730>,
#  'accident_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9790>,
#  'aconseguir_verb': <gensim.models.keyedvectors.Vocab at 0x1390b97f0>,
#  'actor_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9850>,
#  'adaptable_adjective': <gensim.models.keyedvectors.Vocab at 0x1390b98b0>,
#  'aire_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9910>,
#  'alcanzar_verb': <gensim.models.keyedvectors.Vocab at 0x1390b9970>,
#  'antaŭa_adjective': <gensim.models.keyedvectors.Vocab at 0x1390b99d0>,
#  'artificial_adjective': <gensim.models.keyedvectors.Vocab at 0x1390b9a30>,
#  'aspirar_verb': <gensim.models.keyedvectors.Vocab at 0x1390b9a90>,
#  'avance_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9af0>,
#  'baixar_verb': <gensim.models.keyedvectors.Vocab at 0x1390b9b50>,
#  'bank_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9bb0>,
#  'barraca_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9c10>,
#  'barrera_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9c70>,
#  'bola_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9cd0>,
#  'brillar_verb': <gensim.models.keyedvectors.Vocab at 0x1390b9d30>,
#  'cabina_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9d90>,
#  'cadena_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9df0>,
#  'cama_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9e50>,
#  'campo_noun': <gensim.models.keyedvectors.Vocab at 0x1390b9eb0>,
#  ...}

# %%
glove_model.most_similar('science_noun')
# Out:
# [('ciencia_noun', 0.9301629662513733),
#  ('zientzia_noun', 0.5177814960479736),
#  ('impertèrrit_adjective', 0.2623631954193115),
#  ('Hoyales_de_Roa_properNoun', 0.2546602487564087),
#  ('jivarització_noun', 0.24314603209495544),
#  ('uniformjako_noun', 0.23933115601539612),
#  ('ĥaldeo_noun', 0.2355116754770279),
#  ('Carlita_properNoun', 0.23205572366714478),
#  ('alabaster_noun', 0.23179756104946136),
#  ('dializilo_noun', 0.23042315244674683)]

# %%
"""
this function return to the vocabulary from source of dictionary.
input: path of lists dictionaries
output: all word from 'source' tag of these dics. word with form: word_pos
"""

def to_word(list_df):
    words = []
    for path in list_df:
        df = pd.read_csv('../code/Small/' + path)
        words += (df['source'].astype(str) + '_' + df['POS'].astype(str)).to_list()
    return set(words)

# %%
# get all vocabulary
vocabulary = list(glove_model.vocab.keys())

# %%
path_dict_en = ['TransSetEN-CA_small.csv', 'TransSetEN-ES_small.csv', 'TransSetEN-GL_small.csv']
words_en = to_word(path_dict_en)
#interaction beetween words english with vocabulary
words_en = list(set(words_en) & set(vocabulary))
english_vectors = glove_model[words_en]
print(english_vectors.shape)
# Out:
# (47491, 300)

# %%
path_dict_fr = ['TransSetFR-CA_small.csv', 'TransSetFR-ES_small.csv']
words_fr = to_word(path_dict_fr)
words_fr = list(set(words_fr) & set(vocabulary))
france_vectors = glove_model[words_fr]
print(france_vectors.shape)
# Out:
# (62855, 300)

# %%
words_fr[23706]
# Out:
# 'livre_noun'

# %%
#get part of speech of word in vocabulary ex: shape_noun -> noun
def get_pos(word):
    return word.split('_')[-1]

# %%
"""
This function find the trans word most similarity of input word
----------
params:
    word_vec: vector embedding of input word
    matrix_vec_trans: matrix embedding of the target langague
    dic_trans: vocabulary of the target langague
    pos: Part of speech of input word
"""
def find_translate(word_vec, matrix_vec_trans, dic_trans, pos):
    assert len(matrix_vec_trans) == len(dic_trans)
    #calculate the cosine similary of input vec and matrix of target langague
    cosine_similary = glove_model.cosine_similarities(word_vec, matrix_vec_trans) 
    #sort and return index
    # why return negative? :))) 
    sort_cosine = np.argsort(-cosine_similary)
    for index in sort_cosine:
        trans_word = dic_trans[index]
        if(get_pos(trans_word)==pos):
            return trans_word

# %%
# thai_ba_tuan => thai ba tuan
def get_word(word):
    return ' '.join(word.split('_')[0:-1])

# %%
test_word_vec = glove_model['kernel_noun']
cosine_similary = glove_model.cosine_similarities(test_word_vec, france_vectors) 
sort_cosine = np.argsort(-cosine_similary)
for index in sort_cosine[0:10]:
    print(words_fr[index])
# Out:
# lance-grenades_noun
# Eslida_properNoun
# massacrer_verb
# sacrifier_verb
# promission_noun
# uranium_noun
# maison_noun
# XXVIIème_adjective
# Oda_properNoun
# sucrer_verb

# %%
glove_model.similarity('shit_noun', 'merde_noun')
# Out:
# -0.95093447

# %%
# building the dictionary of the word
dict_en_fr = []
index = 0
for word in words_en:
    pos = get_pos(word)
    if index % 1000 == 0:
        print(index,end=' ')
    index+=1
#     print(word)
#     print(pos)
    word_vec = glove_model[word]
    trans_word = find_translate(word_vec, france_vectors, words_fr, pos)
    if trans_word != None:
        trans_word = get_word(trans_word)
#     print(trans_word)
    dict_en_fr.append(get_word(word)+'\t'+str(trans_word)+'\t'+str(pos)+'\t1')
#     print('======================')
# Out:
# 0 1000 2000 3000 4000 5000 6000 7000 8000 9000 10000 11000 12000 13000 14000 15000 16000 17000 18000 19000 20000 21000 22000 23000 24000 25000 26000 27000 28000 29000 30000 31000 32000 33000 34000 35000 36000 37000 38000 39000 40000 41000 42000 43000 44000 45000 46000 47000

# %%
len(dict_en_fr)
# Out:
# 47491

# %%
with open('../code/BuildDictionary/TIADbaseline_glove_trans_en-fr.tsv', 'w') as f:
    for item in dict_en_fr:
        f.write("%s\n" % item)

# %%
# !pwd
# Out:
# /Users/batuan/Documents/Master1Luminy/semetre2/TER/GloVe
