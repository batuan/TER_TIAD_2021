# %%
import onedrivesdk_fork as onedrivesdk
from onedrivesdk.helpers import GetAuthCodeServer
from onedrivesdk.helpers.resource_discovery import ResourceDiscoveryRequest

# %%
redirect_uri = 'http://localhost:8081'
client_id='edc76e4f-618e-4d99-8d69-06a89621c98c'
client_secret = 'I7KDaFk3a3jnu4D_~z9u_tX.FeSD8fqR54'
discovery_uri = 'https://api.office.com/discovery/'
auth_server_url='https://login.microsoftonline.com/common/oauth2/authorize'
auth_token_url='https://login.microsoftonline.com/common/oauth2/token'

http = onedrivesdk.HttpProvider()
auth = onedrivesdk.AuthProvider(http,
                                client_id,
                                auth_server_url=auth_server_url,
                                auth_token_url=auth_token_url)
auth_url = auth.get_auth_url(redirect_uri)
code = GetAuthCodeServer.get_auth_code(auth_url, redirect_uri)
auth.authenticate(code, redirect_uri, client_secret, resource=discovery_uri)
# Out:
# 127.0.0.1 - - [10/May/2021 14:47:49] "GET /?code=0.AREA98TxqfQ4OE2KPEttvpgc6k9ux-2OYZlNjWkGqJYhyYwRAP0.AQABAAIAAAD--DLA3VO7QrddgJg7Wevr0zAVUecydx9TziY1LsUm5T8uCLfQpERm0GyjmMt8W0fjYdg26blZzoUnD48MSxFuHptafSKCrj49xWmk-NDNIdiqE5hgwU6pgQPxz4MvVxXdUa-2Mm1ataEyF1OvpfUC7uLao_4h2uCExsP9ql49Lj73r6uhibdCVVOHdKaIDvcK8UjfreNPwcrF5e2ofKRP4QfdJwoGylPMOEuRkvHsJug6dvWtyx2wlCei7cNId9TVMpymyar00gDYyUSthCrOTk00N_7Cxv7JPpOLQ9SK22xr2FyXQNDlmI5DJYFVzc8XViQmc61BmUGddol6DsXlJo2H_mIbJYd-DfI1Vn-hBFtQepPUNj8Wx_jLU7Ia3Kqk0e1corlq5bukcf325rXxt-Xam5rskXeH5RepDsWzsFh_XZ94X7KMd0m6JpaeITi6bvhTRJWu_j7EeSFQ1CVfHz54P32lju4xrbsEU1c_ClREIRAeOvJC2n39_1HXcmjP2jg3T8kxxkTTp1VPfcGsvILp214HDmicj2Z23zNSdhlUXMRT3QEehpZj1zoCNdsiMXxytje0OMotAOJvtUOVm0MViHuKlLG-OfA7lFVv84h-QPkYW8iQLaaNP2M7llD_c5e5p91IXJDbkTBN6lg7iBYCZFKog_OGmPDXARCn0CAA&session_state=ec06d2a4-82ae-4611-ab55-5957e951e069 HTTP/1.1" 200 -

# %%
# If you have access to more than one service, you'll need to decide
# which ServiceInfo to use instead of just using the first one, as below.
service_info = ResourceDiscoveryRequest().get_service_info(auth.access_token)[0]
auth.redeem_refresh_token(service_info.service_resource_id)
client = onedrivesdk.OneDriveClient(service_info.service_resource_id + '/_api/v2.0/', auth, http)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/envs/ter/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x1098e1a30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.office.com', port=443): Max retries exceeded with url: /discovery/v2.0/me/services (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1098e1a30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-12-1471d3506b45> in <module>
#       1 # If you have access to more than one service, you'll need to decide
#       2 # which ServiceInfo to use instead of just using the first one, as below.
# ----> 3 service_info = ResourceDiscoveryRequest().get_service_info(auth.access_token)[0]
#       4 auth.redeem_refresh_token(service_info.service_resource_id)
#       5 client = onedrivesdk.OneDriveClient(service_info.service_resource_id + '/_api/v2.0/', auth, http)
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/onedrivesdk/helpers/resource_discovery.py in get_service_info(self, access_token)
#      23         """
#      24         headers = {'Authorization': 'Bearer ' + access_token}
# ---> 25         response = json.loads(requests.get(self._discovery_service_url, headers=headers).text)
#      26         service_info_list = [ServiceInfo(x) for x in response['value']]
#      27         trimmed_service_info_list = [si for si in service_info_list
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/ter/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.office.com', port=443): Max retries exceeded with url: /discovery/v2.0/me/services (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1098e1a30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
